# %%
import pandas as pd

# %%
df = pd.read_csv('Pandas ETL.csv')

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp
# 0  2025-01-01 10:05:00
# 1  2025-01-01 10:07:00
# 2  2025-01-01 10:10:00
# 3  2025-01-02 15:20:00
# 4  2025-01-02 15:25:00

# %%
df.tail(3)
# Out:
#     TransactionID  CustomerID            Item     Category  \
# 18              7         107         Journal   Stationery
# 19              8         108      Phone Case  Electronics
# 20              8         108  Travel Adapter  Electronics
#
#       PurchaseTimestamp
# 18  2025-01-07 20:25:00
# 19  2025-01-08 14:50:00
# 20  2025-01-08 14:55:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      21 non-null     int64
#  1   CustomerID         21 non-null     int64
#  2   Item               21 non-null     object
#  3   Category           21 non-null     object
#  4   PurchaseTimestamp  21 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 972.0+ bytes

# %%
df.describe()
# Out:
#        TransactionID  CustomerID
# count      21.000000   21.000000
# mean        4.380952  104.380952
# std         2.355338    2.355338
# min         1.000000  101.000000
# 25%         2.000000  102.000000
# 50%         4.000000  104.000000
# 75%         6.000000  106.000000
# max         8.000000  108.000000

# %%
l1 = df[['CustomerID','Item','TransactionID']]
l1
# Out:
#     CustomerID                Item  TransactionID
# 0          101          Phone Case              1
# 1          101    Screen Protector              1
# 2          101    Wireless Charger              1
# 3          102            Yoga Mat              2
# 4          102        Water Bottle              2
# 5          102      Protein Powder              2
# 6          103          Phone Case              3
# 7          103          Headphones              3
# 8          104    Wireless Charger              4
# 9          104    Portable Speaker              4
# 10         104      Travel Adapter              4
# 11         105            Yoga Mat              5
# 12         105    Resistance Bands              5
# 13         106        Coffee Maker              6
# 14         106        Coffee Beans              6
# 15         106                 Mug              6
# 16         107      Book - Fiction              7
# 17         107  Book - Non-Fiction              7
# ...

# %%
df.loc[0:5]
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
# 5              2         102    Protein Powder      Fitness
#
#      PurchaseTimestamp
# 0  2025-01-01 10:05:00
# 1  2025-01-01 10:07:00
# 2  2025-01-01 10:10:00
# 3  2025-01-02 15:20:00
# 4  2025-01-02 15:25:00
# 5  2025-01-02 15:30:00

# %%
df.iloc[0:9:2]
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 2              1         101  Wireless Charger  Electronics
# 4              2         102      Water Bottle      Fitness
# 6              3         103        Phone Case  Electronics
# 8              4         104  Wireless Charger  Electronics
#
#      PurchaseTimestamp
# 0  2025-01-01 10:05:00
# 2  2025-01-01 10:10:00
# 4  2025-01-02 15:25:00
# 6  2025-01-03 09:10:00
# 8  2025-01-04 12:40:00

# %%
type(df.loc[5, ['Category', 'Item']])
# Out:
# pandas.core.series.Series

# %%
df.loc[4:, ['Category', 'Item']]
# Out:
#        Category                Item
# 4       Fitness        Water Bottle
# 5       Fitness      Protein Powder
# 6   Electronics          Phone Case
# 7   Electronics          Headphones
# 8   Electronics    Wireless Charger
# 9   Electronics    Portable Speaker
# 10  Electronics      Travel Adapter
# 11      Fitness            Yoga Mat
# 12      Fitness    Resistance Bands
# 13      Kitchen        Coffee Maker
# 14      Grocery        Coffee Beans
# 15      Kitchen                 Mug
# 16        Books      Book - Fiction
# 17        Books  Book - Non-Fiction
# 18   Stationery             Journal
# 19  Electronics          Phone Case
# 20  Electronics      Travel Adapter

# %%
df['Category'] == 'Fitness'
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: Category, dtype: bool

# %%
df['CustomerID'] == 101
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: CustomerID, dtype: bool

# %%
df[(df['CustomerID'] == 102) & (df['Category'] == 'Fitness')] 
# comparing two columns
# Out:
#    TransactionID  CustomerID            Item Category    PurchaseTimestamp
# 3              2         102        Yoga Mat  Fitness  2025-01-02 15:20:00
# 4              2         102    Water Bottle  Fitness  2025-01-02 15:25:00
# 5              2         102  Protein Powder  Fitness  2025-01-02 15:30:00

# %%
df['CheckID'] = 'New ' 
# new column added

# %%
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101  Screen Protector  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp CheckID        Combined
# 0  2025-01-01 10:05:00    New   NewElectronics
# 1  2025-01-01 10:07:00    New   NewElectronics
# 2  2025-01-01 10:10:00    New   NewElectronics
# 3  2025-01-02 15:20:00    New       NewFitness
# 4  2025-01-02 15:25:00    New       NewFitness

# %%
df['Combined'] = df['CheckID'].astype(str) + df['Category'].astype(str)

df
# Out:
#     TransactionID  CustomerID                Item     Category  \
# 0               1         101          Phone Case  Electronics
# 1               1         101    Screen Protector  Electronics
# 2               1         101    Wireless Charger  Electronics
# 3               2         102            Yoga Mat      Fitness
# 4               2         102        Water Bottle      Fitness
# 5               2         102      Protein Powder      Fitness
# 6               3         103          Phone Case  Electronics
# 7               3         103          Headphones  Electronics
# 8               4         104    Wireless Charger  Electronics
# 9               4         104    Portable Speaker  Electronics
# 10              4         104      Travel Adapter  Electronics
# 11              5         105            Yoga Mat      Fitness
# 12              5         105    Resistance Bands      Fitness
# 13              6         106        Coffee Maker      Kitchen
# ...

# %%
df.loc[1, 'Item'] = '😂'
df.head()
# Out:
#    TransactionID  CustomerID              Item     Category  \
# 0              1         101        Phone Case  Electronics
# 1              1         101                 😂  Electronics
# 2              1         101  Wireless Charger  Electronics
# 3              2         102          Yoga Mat      Fitness
# 4              2         102      Water Bottle      Fitness
#
#      PurchaseTimestamp CheckID         Combined item
# 0  2025-01-01 10:05:00    New   New Electronics  NaN
# 1  2025-01-01 10:07:00    New   New Electronics    😂
# 2  2025-01-01 10:10:00    New   New Electronics  NaN
# 3  2025-01-02 15:20:00    New       New Fitness  NaN
# 4  2025-01-02 15:25:00    New       New Fitness  NaN

# %%
df.loc[5:15 , 'Category'] = '🗑️' # modified some data
df.head(15)
# Out:
#     TransactionID  CustomerID              Item     Category  \
# 0               1         101        Phone Case  Electronics
# 1               1         101                 😂  Electronics
# 2               1         101  Wireless Charger  Electronics
# 3               2         102          Yoga Mat      Fitness
# 4               2         102      Water Bottle      Fitness
# 5               2         102    Protein Powder           🗑️
# 6               3         103        Phone Case           🗑️
# 7               3         103        Headphones           🗑️
# 8               4         104  Wireless Charger           🗑️
# 9               4         104  Portable Speaker           🗑️
# 10              4         104    Travel Adapter           🗑️
# 11              5         105          Yoga Mat           🗑️
# 12              5         105  Resistance Bands           🗑️
# 13              6         106      Coffee Maker           🗑️
# ...

# %%
# updating multiple columns and rows
df.loc[5:15, ['Category', 'Store']] = ['☝️','👇']
df.head(15)
# Out:
#     TransactionID  CustomerID              Item     Category  \
# 0               1         101        Phone Case  Electronics
# 1               1         101                 😂  Electronics
# 2               1         101  Wireless Charger  Electronics
# 3               2         102          Yoga Mat      Fitness
# 4               2         102      Water Bottle      Fitness
# 5               2         102    Protein Powder           ☝️
# 6               3         103        Phone Case           ☝️
# 7               3         103        Headphones           ☝️
# 8               4         104  Wireless Charger           ☝️
# 9               4         104  Portable Speaker           ☝️
# 10              4         104    Travel Adapter           ☝️
# 11              5         105          Yoga Mat           ☝️
# 12              5         105  Resistance Bands           ☝️
# 13              6         106      Coffee Maker           ☝️
# ...

# %%
df.groupby(['Category']).sum()
# Out:
#              TransactionID  CustomerID  \
# Category
# Books                   14         214
# Electronics             37        1037
# Fitness                 16         516
# Grocery                  6         106
# Kitchen                 12         212
# Stationery               7         107
#
#                                                           Item  \
# Category
# Books                         Book - FictionBook - Non-Fiction
# Electronics  Phone CaseScreen ProtectorWireless ChargerPhon...
# Fitness      Yoga MatWater BottleProtein PowderYoga MatResi...
# Grocery                                           Coffee Beans
# Kitchen                                        Coffee MakerMug
# Stationery                                             Journal
#
#                                              PurchaseTimestamp
# Category
# Books                   2025-01-07 20:15:002025-01-07 20:20:00
# Electronics  2025-01-01 10:05:002025-01-01 10:07:002025-01-...
# ...
